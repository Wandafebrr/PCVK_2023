# %% [markdown]
# <a href="https://colab.research.google.com/github/Wandafebrr/PCVK_2023/blob/main/Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %%
# Membuat list untuk menyimpan url dari beberapa image
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
       "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
      "https://placekitten.com/800/571"]
# loop pada tiap url image, beberapa image dapat disimpan pada list

for url in urls :
  image = io.imread(url)    #read image
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5) #resize image to half size
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)  #convert color to RGB
  final_frame = cv.hconcat((image, image_2))      #concatenate image
  cv2_imshow(final_frame) #show image
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=800x286>

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image : tinggi x lebar = ", tinggi," x ", lebar)
cv2_imshow(image_2)
# Out:
# resolusi image : tinggi x lebar =  286  x  400
# <PIL.Image.Image image mode=RGB size=400x286>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#make horizontal line in the middle of the image
for y in range(lebar):
  image_3[int((tinggi)/2), y]=[255,255,255]

final_frame=cv.hconcat((image_2,image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# **Pertanyaan**
# 1. Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan
# menggunakan Google Colab?
# **Jawab :**
# - Google colab menyediakan akses gratis ke sumber daya komputasi (akses ke GPU dan TPU)
# - Kode dapat dijalankan di cloud tanpa perlu melakukan instalasi atau konfigurasi tambahan pada komputer
# - Google Colab terintegrasi dengan Github dan  Google Drive, yang memungkinkan user menyimpan notebook secara langsung di Drive atau repository mereka, sehingga tidak ada kekhawatiran kehilangan pekerjaan jika sesuatu terjadi pada mesin virtual.
# - Google Colab telah terpasang banyak pustaka dan framework untuk pembelanjaran computer vision terutama di modul praktikum kali ini. Hal ini akan menghemat waktu yang biasanya dibutuhkan untuk mengatur lingkungan pengembangan.
#
# 2. Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke delapan?
# Apakah semua library tersebut harus digunakan dalam praktikgucgegwuum sesi ini?
# **Jawab :** <br>
# a. numpy : library ini menyediakan struktur data seperti array dan fungsi matematika yang kuat, yang berguna untuk mengelola dan  manipulasi data citra seperti mengubah ukuran citra,menghitung statistik, atau melakukan operasi matriks.<br>
# b. Pandas : library ini menyediakan struktur data seperti DataFrame untuk menyimpan dan mengelola data tabular dengan mudah. Pandas digunakan untuk mengorganisir data atau metadata terkait dengan citra.<br>
# c. OpenCV (cv2) : digunakan untuk membaca, memanipulasi, dan menganalisis citra.<br>
# d.  skimage : library untuk pengolahan gambar yang lebih tinggi dalam Python. Modul io dapat digunakan untuk membaca dan menulis citra, sedangkan modul transform berisi berbagai alat untuk transformasi citra.<br>
# e. Pillow (PIL): library untuk pengolahan gambar yang lebih tinggi dan fokus pada operasi citra. Ini digunakan untuk membuka, memanipulasi, dan menyimpan citra dengan format yang berbeda.<br>
# f. matplotlib : library ini membantu dalam visualisasi hasil dari berbagai operasi yang Anda lakukan pada citra.<br>
#
# 3. Pada uji coba langkah ke-9 terdapat potongan kode program : <br>
# **image = cv.resize(image, (0,0), fx=0.5, fy=0.5)** <br>
# Apa kegunaan kode program tersebut?dan apa pengaruhnya jika tidak dilakukan?<br>
# **Jawab :**
# Kode program tersebut digunakan untuk mengubah ukuran gambar. Dalam kasus ini gambar asli akan diperkecil menjadi setengah ukuran aslinya baik dalam arah horizontal maupun vertikal. Jika tidak dilakukan pengaruhnya adalah gambar akan tetap dalam ukuran aslinya sehingga akan memerlukan lebih banyak ruang dan sumber daya komputasi untuk diproses. Selain itu, pengurangan ukuran citra sering digunakan untuk menghemat memori dan waktu pemrosesan
#
# 4. Perhatikan potongan kode progam berikut :
# **for y in range(lebar): <br>
#   image_3[int((tinggi)/2), y]=[255,255,255]** <br>
# Apakah kegunaan kode [255,255,255] ? Jelaskan!<br>
# **Jawab :**
# [255, 255, 255] adalah representasi warna putih dalam format RGB. Dalam konteks Computer Vision, kode ini dapat digunakan untuk membuat garis horizontal atau garis tengah di tengah citra dengan warna putih.
#
# 5. Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun rendah!
# **Jawab :** Resolusi gambar ditentukan oleh jumlah total piksel yang ada dalam gambar tersebut. Semakin banyak piksel yang ada dalam gambar, semakin tinggi resolusinya, dan semakin baik gambar tersebut dapat merepresentasikan detail visual. Ini berarti resolusi gambar yang tinggi dapat menghasilkan gambar yang lebih jelas dan akurat dalam pengolahan citra dan Computer Vision.

# %% [markdown]
# # **TUGAS**

# %%
# Membuat garis vertikal
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for y in range(tinggi):
  image_3[y, int((lebar)/2)] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %%
# Membuat garis diagonal
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

cv.line(image_3, (0, 0), (lebar, tinggi), (255, 255, 255))
cv.line(image_3, (400, 0), (0, tinggi), (255, 255, 255))

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %%
# garis horisontal berwarna putih dibagian tengah gambar dengan panjang tertentu
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for y in range(100,200):
  image_3[int((tinggi)/2), y]=[255,255,255]

final_frame=cv.hconcat((image_2,image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %%
# Membuat kotak
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for y in range(100,200):
  for x in range (100,200):
    image_3[x, y]=[255,255,255]

final_frame=cv.hconcat((image_2,image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# # Tugas Kelompok
# Bentuk kelompok masing-masing terdiri dari 2-3 orang. tiap kelompok lakukan langkah berikut:
# 1. Akses file image lokal (KTP/SIM) dan tampilkan menggunakan OpenCV dan Matplotlib
# 2. Identifikasi kenapa menggunakan konversi warna BGR2RGB pada matplotlib dan tanpa
# konversi pada opencv
# **Jawab:** OpenCV secara default menggunakan format warna BGR (Blue-Green-Red).
# sedangkan matplotlib, menggunakan format warna RGB (Red-Green-Blue) yang lebih umum.
# Ketika gambar dibaca dengan OpenCV, gambar akan dimuat dalam format BGR. Matplotlib mengharapkan gambar dalam format RGB.Tanpa konversi dari BGR ke RGB, gambar akan ditampilkan dengan warna yang salah oleh Matplotlib.
# 3. Tutup tiap bagian tertentu dari kartu identitas tersebut. Kelompok 1 tutup bagian nomor
# NIK dan nama. Kelompok 2 tutup bagian TTL dan Jenis Kelamin. Kelompok 3 tutup bagian
# Gol. Darah dan TTD. Kelompok 4 tutup bagian Alamat dan Kecamatan. Kelompok 5 tutup
# bagian Agama dan Status Kawin. Kelompok 6 tutup Pekerjaan dan kewarganegaraan.
# Kelompok 7 tutup bagian berlaku hingga dan foto. Kelompok 8 tutup bagian kabupaten
# dan tanggal dikeluarkan KTP yang ada dibagian bawah foto. Kelompok 9 tutup bagian
# nama propinsi dan kabupaten di bagian paling atas KTP. Kelompok 10 tutup bagian RT/RW
# dan Kel/desa. Tutup menggunakan 2 kotak warna yang berbeda. Tidak boleh
# menggunakan fungsi rectangle openCV, fungsi ini akan dipelajari pada pertemuan 2.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/pcvk/KTP.jpeg'
img1= cv.imread(path)
img1 = cv.cvtColor(img1,cv.COLOR_BGR2RGB)
plt.imshow(img1)

# %%
img1[70:110,195:540] = [248,253,95]
img1[120:140,190:540] = [0,0,0]
plt.imshow(img1)
